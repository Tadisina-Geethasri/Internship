# %%
#importing required librarires
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# As per the dataset we can observe that all the columns are of int datatype and ERA is the float data type. we can see that the target variable is W.

# %%
df.shape
# Out:
# (30, 17)

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# we can observe unique values in all the columns

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# we can observe that there are no null values in the dataset

# %%
df.isna()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %% [markdown]
# we can observe that there are no missing and duplicate values in the dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# we can observe that there are non negative values in the dataset

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
pltnum = 1
for column in df:
    if pltnum<=17:
        ax = plt.subplot(10,2,pltnum)
        sb.distplot(df[column], color = 'red')
        plt.xlabel(column, fontsize = 18)
    pltnum +=1
plt.show()

# %% [markdown]
# we can observe that the columns R,SO,CG and E are nont normally distributed

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
plotnumber = 1 
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sb.histplot(df[column], color = 'red')
        plt.xlabel(column, fontsize = 20)
    plotnumber +=1
plt.show()

# %%
plt.figure (figsize = (20,50), facecolor = 'white')
pltnum = 1
for column in df:
    if pltnum <=17:
        ax = plt.subplot(10,2,pltnum)
        sb.boxplot(df[column], color='red')
        plt.xlabel(column, fontsize=18)
    pltnum +=1
plt.show()

# %% [markdown]
# outliers are seen in R, ERA, SHO, SV and E.So these outliers should be handled in later steps.

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
pltnum = 1

for column in df:
    if pltnum <=20:
        ax = plt.subplot(7,4,pltnum)
        plt.scatter(df[column],df['W'], color='r')
        plt.xlabel(column,fontsize=18)
        plt.ylabel('W', fontsize=18)
    pltnum += 1
plt.show()

# %% [markdown]
# we can observe lonear relationship between target variable  W and SV, ERA, SHO and R. Non linear relationship between W and other columns

# %%
#Multivariant Analysis
sb.pairplot(df)
plt.show()

# %%
#Heatmap Analysis
plt.figure(figsize = [20,15])
sb.heatmap(df.corr(),annot = True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# we can observe that RA, ER, ERA are highly correlated with each other. There is a negative correlation between W and RA, ER, ERA.

# %%
#Checking for outliers
df.plot(kind='box',fontsize=15,figsize=(25,25),color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can observe the outliers R, ERA, SHO SV and E

# %%
#z-score
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df=df[(z<3).all(axis=1)]
df
# Out:
#       W    R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1    83  696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3    76  622  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 6    87  764  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7    81  713  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9    78  748  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10   88  751  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# 11   86  729  5459  7.218177  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
df.shape
# Out:
# (29, 17)

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# we can observe skewness in H, CG, SHO, SV, and E

# %%
#remove skewness
skew_features=['H','CG','SHO','SV','E']

# %%
df['H'] = np.log1p(df['H'])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method = 'yeo-johnson')
df[['E','SHO','SV','CG']] = scaler.fit_transform(df[['E','SHO','SV','CG']].values)

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.732868
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.006996
# SHO    0.032659
# SV    -0.033949
# E     -0.015812
# dtype: float64

# %%
#splitting the columns
x = df.drop('W',axis = 1)
y = df['W']

# %%
#scaling 
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
sc = StandardScaler()
X = pd. DataFrame(sc. fit_transform(x), columns = x.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.106188        R
# 1      20.527285       AB
# 2      10.191115        H
# 3       3.536911       2B
# 4       3.243748       3B
# 5       8.741692       HR
# 6       3.319054       BB
# 7       2.815722       SO
# 8       1.958219       SB
# 9     201.866794       RA
# 10   2098.188387       ER
# 11   1628.229557      ERA
# 12      2.927243       CG
# 13      3.286693      SHO
# 14      5.992427       SV
# 15      2.358941        E

# %% [markdown]
# we can observe that multicollinearity is present in RA, ER, ERA.

# %%
x = x.drop(["ER"], axis = 1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.106188        R
# 1      20.527285       AB
# 2      10.191115        H
# 3       3.536911       2B
# 4       3.243748       3B
# 5       8.741692       HR
# 6       3.319054       BB
# 7       2.815722       SO
# 8       1.958219       SB
# 9     201.866794       RA
# 10   2098.188387       ER
# 11   1628.229557      ERA
# 12      2.927243       CG
# 13      3.286693      SHO
# 14      5.992427       SV
# 15      2.358941        E

# %%
x = x.drop(["ERA"], axis = 1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.106188        R
# 1      20.527285       AB
# 2      10.191115        H
# 3       3.536911       2B
# 4       3.243748       3B
# 5       8.741692       HR
# 6       3.319054       BB
# 7       2.815722       SO
# 8       1.958219       SB
# 9     201.866794       RA
# 10   2098.188387       ER
# 11   1628.229557      ERA
# 12      2.927243       CG
# 13      3.286693      SHO
# 14      5.992427       SV
# 15      2.358941        E

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
# model
from sklearn.linear_model import  LinearRegression
lr=LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)
lr.fit(x_train,y_train)
lr_predict_train=lr.predict(x_train)
lr_predict_test=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('accuracy', lr.score(x_train,y_train))
print('MSE:',mean_squared_error(lr_predict_test,y_test))
print('MAE:',mean_absolute_error(lr_predict_test,y_test))
print('r2_score:',r2_score(lr_predict_test,y_test))
# Out:
# accuracy 0.9296510217185519
# MSE: 30.783338285076063
# MAE: 4.62301802347173
# r2_score: 0.6807647449466496

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: -5.105239557936964e+29
# mae: 6.926455628809172e+31
# mae: 8168999037752304.0
# rmse: 8322533045178716.0

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8419450548869434
# mse: 21.4438627573796
# mae: 4.320226469102721
# rmse: 4.630751856597327

# %%
from sklearn.linear_model import  LogisticRegression
log_r=LogisticRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)
log_r.fit(x_train,y_train)
log_r_predict_train=log_r.predict(x_train)
log_r_predict_test=log_r.predict(x_test)

# %%
print('accuracy', log_r.score(x_train,y_train))
print('MSE:',mean_squared_error(log_r_predict_test,y_test))
print('MAE:',mean_absolute_error(log_r_predict_test,y_test))
print('r2_score:',r2_score(log_r_predict_test,y_test))
# Out:
# accuracy 1.0
# MSE: 40.857142857142854
# MAE: 5.714285714285714
# r2_score: 0.5076242006886376

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model,x,y):
    rmse =-(cross_val_score(model,x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)

models = [LinearRegression(),
         Ridge(),
         SVR(kernel='linear'),
         SVR(kernel='poly'),
         SVR(kernel='rbf'),
         RandomForestRegressor(),
         DecisionTreeRegressor(),
         GradientBoostingRegressor(),]

names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : 33.557880, 20.776517
# R   : 30.122369, 20.408378
# svr   : 39.358344, 34.765906
# svr_p   : 112.171878, 79.911516
# svr_r   : 112.379529, 79.843845
# RF   : 42.766498, 27.326702
# DTR   : 81.550000, 56.713610
# GBR   : 53.566123, 34.538658

# %%
#hyperparameter tuning
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000],
            'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GVC.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 6,
#  'selection': 'random',
#  'tol': 1000}

# %%
Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=4, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 86.27132817050511
# mean_squared_error: 18.626165371935116
# mean_absolute_error: 3.339394591828955
# RMSE value: 4.315804139663328

# %%
#Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']
